# %%
# %matplotlib inline 
#to enable automatic visualization of your plots when the cell has finished executing.
#function that renders the figure in a notebook (instead of displaying a dump of the figure object 

import matplotlib.pyplot as plt
 
#Plot a line graph
plt.plot([5, 15, 2, 3])
 
# Add labels and title
plt.title("Interactive Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
#plt.show()

# %%
# conda install -c conda-forge skater 
# conda install -c conda-forge/label/cf201901 skater
