# %% [markdown]
# # Exploration Methods
# When you receive a CSV file from an external source, you'll want to get a feel for the data.
#
# Let's import some data and then learn how to explore it.

# %%
# Setup
import os
import pandas as pd

# We use os.path.join because Windows uses a back slash (\) to separate directories
#  while others use a forward slash (/)
users_file_name = os.path.join('data', 'users.csv')
users_file_name
# Out:
# 'data/users.csv'

# %%
os.getcwd()
# Out:
# '/Users/brianho/smart_sel_day1b/pandas'

# %% [markdown]
# ## CSV File Exploration
# If you want to take a peek at your CSV file, you could open it in an editor.
#
# Let's just use some standard Python to see the first couple lines of the file.

# %%
with open(users_file_name) as lines:
    print(lines.read())
# Out:
# ,first_name,last_name,email,email_verified,signup_date,referral_count,balance
# aaron,Aaron,Davis,aaron6348@gmail.com,True,2018-08-31,6,18.14
# acook,Anthony,Cook,cook@gmail.com,True,2018-05-12,2,55.45
# adam.saunders,Adam,Saunders,adam@gmail.com,False,2018-05-29,3,72.12
# adrian,Adrian,Fang,adrian.fang@teamtreehouse.com,True,2018-04-28,3,30.01
# adrian.blair,Adrian,Blair,adrian9335@gmail.com,True,2018-06-16,7,25.85
# alan9443,Alan,Pope,pope@hotmail.com,True,2018-04-17,0,56.09
# alexander7808,Alexander,Moore,alexander.moore@gmail.com,False,2018-03-27,2,87.71
# alvarado,Denise,Alvarado,alvarado@hotmail.com,True,2018-09-07,6,26.72
# alvarez,John,Alvarez,john4346@hotmail.com,True,2018-09-18,6,49.62
# amanda,Amanda,Lynch,alynch@gmail.com,True,2018-09-18,2,43.76
# amiller,Anne,Miller,miller@hotmail.com,False,2018-06-02,5,86.28
# andersen,Mark,Andersen,mark.andersen@yahoo.com,True,2018-08-21,3,75.69
# andrade,Melissa,Andrade,mandrade@yahoo.com,True,2018-01-06,3,83.22
# andrew.alvarez,Andrew,Alvarez,aalvarez@hotmail.com,False,2018-08-01,0,81.66
# andrew.wells,Andrew,Wells,andrew9976@yahoo.com,True,2018-06-13,5,76.07
# andrew6216,Andrew,Bryan,andrew@gmail.com,True,2018-04-01,1,71.42
# andrew6347,Andrew,Horton,andrew.horton@hotmail.com,True,2018-02-01,2,85.73
# angela7209,Angela,Collins,collins5797@yahoo.com,True,2018-05-05,7,29.52
# anthony1788,Anthony,Valdez,anthony@gmail.com,True,2018-06-30,5,70.7
# anthony3761,Anthony,,anthony9581@gmail.com,True,2018-08-16,6,59.81
# anthony576,Anthony,Lane,anthony@yahoo.com,True,2018-03-22,7,42.6
# april9082,April,Santana,april.santana@hotmail.com,True,2018-08-14,2,53.87
# ariley,Alexis,Riley,ariley@gmail.com,True,2018-05-10,2,89.22
# arosario,Amanda,Rosario,amanda@yahoo.com,True,2018-01-29,1,76.19
# atapia,Amy,Tapia,amy@hotmail.com,True,2018-02-06,5,67.96
# austin,Austin,Ashley,austin5493@gmail.com,True,2018-03-12,7,70.38
# austin486,Austin,Ward,ward@hotmail.com,True,2018-01-04,7,0.48
# awhitney,Amanda,Whitney,whitney6923@yahoo.com,True,2018-04-06,2,30.85
# awilliams,Amanda,Williams,williams4190@yahoo.com,True,2018-09-15,7,24.8
# barnes,Mikayla,Barnes,mikayla.barnes@hotmail.com,True,2018-06-15,1,1.71
# bernard,Dean,Bernard,dean.bernard@gmail.com,True,2018-02-03,6,45.67
# bgreen,Brenda,Green,brenda.green@gmail.com,True,2018-02-17,7,47.89
# bishop,Mason,Bishop,bishop@gmail.com,True,2018-02-14,5,4.59
# blair4952,Nicole,Blair,nicole.blair@yahoo.com,True,2018-04-22,2,32.62
# blankenship,April,Blankenship,blankenship11@gmail.com,True,2018-01-12,3,48.31
# bowers9648,John,Bowers,bowers5600@hotmail.com,True,2018-06-19,4,36.92
# bowman,Mary,Bowman,mary.bowman@sanchez.net,True,2018-04-13,3,54.21
# boyer7005,Sara,Boyer,boyer8636@gmail.com,True,2018-07-31,0,91.41
# bpowers,Bryce,Powers,bryce@yahoo.com,True,2018-02-28,2,17.99
# bradley,Bradley,,bradley3941@henderson.com,True,2018-06-24,4,22.24
# bradley3953,Bradley,Mills,mills6497@hotmail.com,True,2018-05-16,3,43.89
# bradley7808,Bradley,,bradley8794@yahoo.com,True,2018-06-15,1,76.49
# brandon,Brandon,King,bking@gmail.com,True,2018-02-15,5,56.25
# brandon.gilbert,Brandon,Gilbert,brandon.gilbert@hotmail.com,True,2018-04-28,0,10.17
# brenda,Brenda,,brenda@hotmail.com,True,2018-07-28,7,6.18
# brett643,Brett,Sanchez,sanchez4831@hotmail.com,True,2018-01-03,6,30.8
# brian.barnes,Brian,Barnes,brian.barnes@hotmail.com,True,2018-06-15,7,92.28
# brian7426,Brian,Santiago,brian843@hotmail.com,True,2018-03-18,1,85.41
# brooke2027,Brooke,,brooke6938@gmail.com,False,2018-05-23,0,7.22
# brown,Kyle,Brown,brown9052@hotmail.com,True,2018-02-27,2,43.87
# brown6798,Julia,Brown,julia.brown@bishop.com,True,2018-09-10,4,16.4
# bryant,Darlene,Bryant,dbryant@yahoo.com,True,2018-07-19,0,36.91
# bsmith,Benjamin,Smith,benjamin5212@hotmail.com,True,2018-08-05,3,15.77
# burton6737,Darrell,Burton,burton@yahoo.com,True,2018-03-09,6,12.29
# butler,Amy,Butler,amy4529@hotmail.com,True,2018-05-04,4,83.31
# caleb,Caleb,Ellison,ellison@gmail.com,True,2018-04-17,1,36.84
# calvin.perez,Calvin,Perez,cperez@gmail.com,True,2018-02-17,0,13.01
# campbell1062,Amber,Campbell,amber.campbell@gmail.com,True,2018-01-10,3,35.66
# campbell4312,Charlotte,Campbell,campbell@hotmail.com,True,2018-03-02,0,11.83
# carl.fox,Carl,Fox,fox@hotmail.com,True,2018-04-29,6,19.13
# cassandra,Cassandra,,cassandra9220@gmail.com,True,2018-05-03,5,78.9
# chad.chen,Chad,Chen,chad.chen@hotmail.com,True,2018-02-09,7,7.5
# charles,Charles,Tran,tran6961@yahoo.com,True,2018-02-20,6,40.79
# charles559,Charles,Smith,smith@hotmail.com,True,2018-04-16,6,77.05
# chorne,Christopher,Horne,horne@gmail.com,True,2018-03-28,4,28.49
# christina.banks,Christina,Banks,cbanks@yahoo.com,True,2018-03-03,2,88.91
# christine.brown,Christine,Brown,brown@hotmail.com,True,2018-05-05,4,67.24
# christine2983,Christine,,christine3128@gmail.com,False,2018-05-23,5,94.02
# christopher,Christopher,,christopher@gmail.com,True,2018-07-24,3,96.96
# christopher5982,Christopher,Martin,martin@yahoo.com,False,2018-08-22,3,4.32
# christopher6861,Christopher,Mitchell,mitchell@hotmail.com,False,2018-06-20,4,55.46
# cjimenez,Charles,Jimenez,charles8775@gmail.com,True,2018-02-17,0,55.84
# cjones,Carla,Jones,carla2889@gmail.com,True,2018-06-23,1,33.32
# clark8139,Tara,Clark,clark@gmail.com,True,2018-01-26,6,93.23
# clayton6074,Robert,Clayton,robert@gmail.com,True,2018-01-12,7,97.05
# coleman,Amber,Coleman,amber1175@yahoo.com,True,2018-05-17,5,15.79
# collin,Collin,,collin@gmail.com,False,2018-08-18,7,89.95
# collins,Tyler,Collins,tyler.collins@hotmail.com,True,2018-08-16,6,94.69
# colton,Colton,Burke,colton9297@yahoo.com,True,2018-02-12,6,57.98
# conley,Courtney,Conley,conley140@gmail.com,True,2018-06-23,2,26.28
# corey,Corey,Fuller,fuller8100@yahoo.com,True,2018-04-19,3,31.56
# corey.ingram,Corey,Ingram,corey.ingram@gmail.com,True,2018-09-11,1,69.54
# courtney9644,Courtney,Macias,courtney.macias@hotmail.com,True,2018-07-14,6,25.18
# cox192,Eric,Cox,eric@hotmail.com,True,2018-06-24,3,0.05
# crane203,Valerie,Crane,valerie7051@hotmail.com,True,2018-05-12,3,98.69
# cross9059,Emily,Cross,emily8281@gmail.com,True,2018-01-07,7,83.62
# cynthia5799,Cynthia,Castillo,ccastillo@moore.org,True,2018-03-09,0,91.83
# dale,Dale,Salinas,dale@gmail.com,True,2018-04-01,2,19.61
# dana.andrews,Dana,Andrews,dandrews@thomas.org,True,2018-09-16,4,54.68
# danderson,David,Anderson,david@hotmail.com,True,2018-07-22,6,49.52
# daniel,Daniel,Allen,allen@hotmail.com,False,2018-07-01,2,21.21
# daniel.livingston,Daniel,Livingston,livingston794@yahoo.com,True,2018-06-22,5,29.66
# daniel.williams,Daniel,Williams,williams6378@yahoo.com,True,2018-03-13,4,93.85
# daniel1611,Daniel,Morales,morales8909@gmail.com,False,2018-05-15,7,60.66
# danielle,Danielle,Salazar,danielle4662@drake.com,True,2018-03-21,3,45.09
# darlene.adams,Darlene,Adams,adams@hotmail.com,True,2018-09-15,2,67.02
# david,David,,david300@gmail.com,True,2018-03-28,0,59.74
# david.barnett,David,Barnett,barnett462@hotmail.com,True,2018-02-21,2,46.88
# david2796,David,Mcclure,david3888@hotmail.com,True,2018-09-16,5,37.6
# david5498,David,Garcia,david2998@hotmail.com,True,2018-01-05,4,29.14
# davis,Erica,Davis,erica@gmail.com,True,2018-06-08,2,53.52
# davis9225,Laura,Davis,laura@hotmail.com,True,2018-03-19,3,51.81
# davis9792,David,Davis,davis3883@hotmail.com,True,2018-01-04,4,36.9
# dawn,Dawn,,dawn6718@hotmail.com,True,2018-03-02,2,72.63
# dawn.juarez,Dawn,Juarez,dawn@hotmail.com,True,2018-04-13,1,16.38
# dean,Lynn,Dean,dean@gmail.com,True,2018-05-22,3,17.45
# dean2365,Brian,Dean,dean3892@hotmail.com,True,2018-01-08,6,8.5
# debbie4918,Debbie,,debbie3109@hotmail.com,True,2018-02-09,7,73.63
# debra,Debra,Frazier,frazier@yahoo.com,True,2018-06-01,1,80.71
# decker1985,Robert,Decker,robert@yahoo.com,True,2018-04-04,7,92.55
# dedwards,Deborah,Edwards,deborah@hotmail.com,False,2018-01-13,0,25.63
# denise3770,Denise,Cabrera,cabrera@hotmail.com,False,2018-07-21,1,95.08
# dennis,Trevor,Dennis,dennis@gmail.com,True,2018-04-29,2,10.04
# dennis4593,Ann,Dennis,ann.dennis@christensen.com,True,2018-04-23,6,79.24
# diana,Diana,Wagner,wagner8014@gmail.com,True,2018-01-15,4,19.45
# diana1995,Diana,Gregory,gregory@gmail.com,True,2018-03-22,4,51.81
# diane4652,Diane,,diane9705@yahoo.com,False,2018-08-17,1,62.05
# donald1420,Donald,,donald1129@gmail.com,True,2018-08-24,2,74.58
# donald3362,Donald,Kennedy,donald@small.biz,False,2018-04-01,2,81.06
# donna1922,Donna,Castillo,donna.castillo@hotmail.com,True,2018-02-18,7,77.79
# dustin.fowler,Dustin,Fowler,dustin@yahoo.com,True,2018-04-09,2,37.8
# ebryant,Erik,Bryant,bryant@yahoo.com,True,2018-07-21,6,31.49
# edward1527,Edward,,edward1672@yahoo.com,False,2018-03-07,3,69.63
# edwards,Michael,Edwards,edwards5456@gmail.com,True,2018-05-06,4,83.33
# edwards8658,Alan,Edwards,alan8469@hotmail.com,False,2018-02-24,1,24.93
# ehaney,Emily,Haney,haney@gmail.com,True,2018-06-12,3,64.65
# eharding,Eric,Harding,eric1206@yahoo.com,True,2018-08-25,1,42.71
# ehernandez,Elizabeth,Hernandez,elizabeth.hernandez@gmail.com,True,2018-08-21,1,69.17
# ekidd,Elizabeth,Kidd,kidd7082@hotmail.com,True,2018-08-01,7,13.14
# elaine,Elaine,,elaine@yahoo.com,False,2018-04-20,5,45.2
# elang,Erica,Lang,lang@gmail.com,True,2018-03-24,2,77.66
# elizabeth,Elizabeth,Johnson,johnson913@yahoo.com,True,2018-02-20,1,77.91
# emily,Emily,,emily7694@hotmail.com,True,2018-06-29,2,89.16
# emily.anderson,Emily,Anderson,emily7106@gmail.com,True,2018-02-21,0,77.69
# emily.lewis,Emily,Lewis,lewis8915@yahoo.com,True,2018-01-13,4,57.51
# epeters,Emily,Peters,emily.peters@hotmail.com,True,2018-05-09,1,64.91
# eric1415,Eric,Moon,emoon@yahoo.com,True,2018-04-25,6,39.16
# erin,Erin,Robinson,erin@gmail.com,True,2018-06-17,7,70.32
# erin4486,Erin,Wright,erin.wright@gmail.com,True,2018-05-31,5,76.18
# eugene4448,Eugene,,eugene@gmail.com,True,2018-06-08,0,95.38
# evelyn,Evelyn,Spencer,evelyn.spencer@yahoo.com,False,2018-07-29,6,6.25
# fernandez,Theresa,Fernandez,theresa@gmail.com,True,2018-01-13,5,47.13
# figueroa7283,Amy,Figueroa,figueroa@gmail.com,True,2018-07-27,3,36.5
# fisher,Kenneth,Fisher,kenneth.fisher@ryan.net,True,2018-05-11,0,88.87
# fitzgerald,William,Fitzgerald,wfitzgerald@pham-nguyen.com,True,2018-05-18,0,39.04
# flores,Catherine,Flores,catherine346@oneal-roberts.info,True,2018-05-01,0,3.97
# fox,David,Fox,fox@yahoo.com,True,2018-09-05,7,86.65
# francis.hernandez,Francis,Hernandez,hernandez5650@hotmail.com,True,2018-02-12,3,28.44
# freeman,Tamara,Freeman,tfreeman@yahoo.com,True,2018-04-22,7,51.72
# fuentes,Alexander,Fuentes,alexander1368@gmail.com,True,2018-08-03,0,86.57
# fuller3354,Nicole,Fuller,fuller@hotmail.com,False,2018-04-08,7,14.4
# gail2190,Gail,Klein,gklein@yahoo.com,True,2018-08-17,4,48.7
# gail7896,Gail,Clarke,clarke@gmail.com,True,2018-05-05,1,67.14
# gary.mitchell,Gary,Mitchell,mitchell1601@davidson-wilson.com,False,2018-04-08,4,76.19
# gerald.bryant,Gerald,Bryant,gerald.bryant@yahoo.com,True,2018-04-15,5,87.08
# gibson9198,Jason,Gibson,jason4132@yahoo.com,True,2018-04-12,6,85.34
# glen9827,Glen,Hawkins,glen8942@gmail.com,True,2018-02-02,5,27.72
# grace7647,Grace,Payne,grace546@yahoo.com,True,2018-03-14,5,38.41
# graham,Christopher,Graham,cgraham@hotmail.com,True,2018-07-06,3,18.18
# grant1643,Jay,Grant,grant3970@hotmail.com,True,2018-01-25,7,3.01
# greg5920,Greg,Kelley,greg1612@gmail.com,True,2018-01-02,6,29.16
# gregory.blackwell,Gregory,Blackwell,gblackwell@frost-white.com,True,2018-01-10,3,63.14
# gregory.rios,Gregory,Rios,gregory@gmail.com,True,2018-01-13,4,16.42
# gregory7148,Jon,Gregory,gregory@keller-moran.net,True,2018-01-11,6,15.62
# gregory9829,Gregory,Webb,gregory.webb@yahoo.com,True,2018-09-01,5,68.07
# griffin4992,Kaitlin,Griffin,kaitlin.griffin@yahoo.com,True,2018-03-10,7,22.68
# gstevens,Gabriella,Stevens,gabriella@gmail.com,False,2018-05-10,6,3.64
# guzman4000,Ronald,Guzman,rguzman@gmail.com,True,2018-07-10,4,50.26
# hall,George,Hall,hall@gmail.com,True,2018-03-14,3,85.4
# hamilton,Douglas,Hamilton,hamilton6279@gmail.com,True,2018-06-30,1,58.98
# hamilton4258,Mary,Hamilton,hamilton@yahoo.com,True,2018-03-30,4,72.44
# harmon,Justin,Harmon,justin.harmon@hotmail.com,False,2018-04-12,4,91.87
# harold,Harold,Willis,willis9328@yahoo.com,False,2018-05-07,1,6.0
# harris7556,Kelli,Harris,kharris@gmail.com,True,2018-06-18,0,53.44
# hart24,Teresa,Hart,teresa778@lucas.biz,False,2018-05-18,4,16.69
# hayes2585,Daniel,Hayes,dhayes@gmail.com,True,2018-05-10,7,22.64
# hdeleon,Hannah,Deleon,hannah@yahoo.com,True,2018-09-12,6,48.93
# heather,Heather,Ray,hray@yahoo.com,True,2018-05-14,5,41.65
# heather.wade,Heather,Wade,heather.wade@yahoo.com,True,2018-09-25,0,45.95
# hector,Hector,Bowers,hbowers@hotmail.com,True,2018-07-09,0,21.24
# helen5691,Helen,Simmons,simmons695@gmail.com,True,2018-03-02,3,93.83
# henry,Steven,Henry,steven.henry@gmail.com,True,2018-03-07,1,12.58
# henry4707,Nancy,Henry,nancy.henry@gmail.com,True,2018-03-02,3,73.17
# higgins,Duane,Higgins,higgins@gmail.com,True,2018-04-03,5,62.12
# hmiller,Howard,Miller,howard6112@yahoo.com,True,2018-04-25,6,64.03
# holden4580,Jason,Holden,holden@gmail.com,True,2018-01-17,3,7.95
# hoover4302,Michelle,Hoover,mhoover@hotmail.com,True,2018-02-09,0,37.38
# hunt3408,Ethan,Hunt,hunt7143@gmail.com,False,2018-06-23,3,62.81
# isabella,Isabella,Golden,isabella@perez-schultz.net,False,2018-07-24,5,65.71
# jackson4431,Melissa,Jackson,jackson@gmail.com,True,2018-02-06,7,69.32
# jacob,Jacob,Rose,rose@yahoo.com,True,2018-07-15,4,2.85
# jacob.davis,Jacob,Davis,jdavis@gmail.com,False,2018-09-16,0,95.7
# jaime6887,Jaime,Johnson,johnson@garcia-contreras.org,False,2018-01-19,4,81.6
# james,James,Nichols,nichols@ramirez.com,False,2018-09-06,5,88.7
# janet.williams,Janet,Williams,janet9480@hotmail.com,True,2018-05-31,0,71.53
# jason,Jason,Nguyen,nguyen7758@yahoo.com,True,2018-04-30,1,60.4
# jason4651,Jason,Parks,jason@yahoo.com,True,2018-09-03,3,40.76
# jason7792,Jason,Holland,jholland@hotmail.com,False,2018-01-18,0,22.37
# jbarker,Joe,Barker,joe@yahoo.com,False,2018-08-12,3,68.91
# jcastaneda,Joshua,Castaneda,jcastaneda@yahoo.com,False,2018-05-06,7,53.54
# jcoleman,Jason,Coleman,jason3300@gmail.com,True,2018-05-18,7,59.62
# jcordova,Jennifer,Cordova,jcordova@hotmail.com,True,2018-02-27,0,31.72
# jdiaz,Jay,Diaz,jdiaz@yahoo.com,False,2018-05-28,4,25.43
# jeffrey,Jeffrey,Stewart,stewart7222@hotmail.com,True,2018-01-02,0,40.58
# jennifer,Jennifer,Dean,jdean@davis-warren.com,True,2018-04-26,6,70.26
# jennifer.hebert,Jennifer,Hebert,jennifer.hebert@yahoo.com,True,2018-07-24,5,16.27
# jennifer.hendrix,Jennifer,Hendrix,hendrix1706@gmail.com,True,2018-01-15,0,37.2
# jennifer.walker,Jennifer,Walker,walker6745@yahoo.com,False,2018-03-18,0,60.79
# jennifer.wong,Jennifer,Wong,jwong@yahoo.com,True,2018-07-03,7,95.1
# jennifer4743,Jennifer,Carter,jennifer.carter@gmail.com,True,2018-08-28,6,33.33
# jensen7832,Steven,Jensen,steven.jensen@hotmail.com,True,2018-05-20,3,22.04
# jeremy1104,Jeremy,Warren,jwarren@hotmail.com,True,2018-04-01,0,74.38
# jerome.sims,Jerome,Sims,sims141@gmail.com,True,2018-09-13,7,34.31
# jerry,Jerry,Mathis,jmathis@hotmail.com,True,2018-04-15,4,8.75
# jessica,Jessica,,jessica@gmail.com,True,2018-06-14,2,23.09
# jessica3924,Jessica,Preston,preston5688@yahoo.com,True,2018-09-04,3,42.68
# jesus9614,Jesus,Johnson,johnson6528@gmail.com,True,2018-07-12,6,31.75
# jgonzalez,Jenny,Gonzalez,jenny.gonzalez@hotmail.com,True,2018-06-03,1,0.59
# jholloway,Julia,Holloway,julia9698@gmail.com,False,2018-09-08,6,16.27
# jlong,Jessica,Long,jessica7275@gmail.com,True,2018-07-11,3,63.12
# joel8826,Joel,Gates,joel516@hotmail.com,False,2018-03-05,4,71.6
# john,John,,john@hotmail.com,True,2018-09-24,3,84.67
# john.hardy,John,Hardy,hardy@gmail.com,True,2018-03-02,1,51.57
# john.smith,John,Smith,john.smith@hotmail.com,True,2018-06-24,4,21.01
# john6967,John,Vance,jvance@yahoo.com,True,2018-06-24,0,0.42
# johnson,Brian,Johnson,johnson@hotmail.com,True,2018-09-11,7,12.23
# johnson3004,Donald,Johnson,donald.johnson@gmail.com,True,2018-03-03,0,38.51
# johnston2281,Nicholas,Johnston,njohnston@yahoo.com,True,2018-07-08,0,9.22
# jonathan5101,Jonathan,Hayes,hayes1910@yahoo.com,True,2018-09-03,1,65.5
# jones,Erin,Jones,erin.jones@yahoo.com,True,2018-01-25,2,86.66
# jones5796,Katherine,Jones,jones@yahoo.com,True,2018-04-11,1,6.41
# jordan5739,Jordan,Clayton,clayton@gmail.com,True,2018-06-26,1,81.47
# jose.moreno,Jose,Moreno,jose@hotmail.com,True,2018-04-10,5,73.64
# joseph.lopez,Joseph,Lopez,joseph@gmail.com,True,2018-08-12,6,65.99
# joseph2431,Joseph,Harris,joseph@gmail.com,True,2018-03-07,5,95.47
# joshua.henry,Joshua,Henry,joshua@hotmail.com,True,2018-01-05,2,80.03
# joshua3747,Joshua,,joshua@hotmail.com,True,2018-05-22,0,11.7
# joshua9690,Joshua,White,jwhite@hotmail.com,False,2018-03-27,7,47.31
# jramos,Joshua,Ramos,joshua@yahoo.com,True,2018-07-10,6,75.56
# jramsey,Jeremy,Ramsey,jeremy.ramsey@gmail.com,True,2018-02-18,5,58.74
# jreeves,Jill,Reeves,reeves4581@yahoo.com,True,2018-07-27,2,56.56
# jserrano,Jillian,Serrano,jillian@yahoo.com,True,2018-06-12,5,41.25
# jstewart,Juan,Stewart,stewart@yahoo.com,True,2018-08-15,4,87.53
# kallen,Kathy,Allen,kathy@hotmail.com,False,2018-02-20,1,43.72
# kara,Kara,Ortega,kara9172@hotmail.com,True,2018-03-22,2,9.17
# karen.snow,Karen,Snow,ksnow@yahoo.com,True,2018-05-06,2,99.38
# katherine,Katherine,,katherine@yahoo.com,False,2018-01-26,3,59.06
# kathy,Kathy,,kathy@gmail.com,False,2018-04-30,0,8.9
# katrina.ingram,Katrina,Ingram,kingram@harris.com,True,2018-02-18,7,27.4
# keith,Keith,Mercado,keith.mercado@yahoo.com,True,2018-05-21,2,0.85
# keith2323,Keith,Lewis,keith.lewis@yahoo.com,True,2018-03-08,2,79.86
# kelly5683,Kelly,Welch,kelly@hotmail.com,True,2018-09-20,5,9.24
# kelly7722,Kelly,Knapp,knapp@yahoo.com,False,2018-05-20,0,73.62
# kenneth.chambers,Kenneth,Chambers,kchambers@hotmail.com,True,2018-03-27,6,55.98
# kent,Kayla,Kent,kent98@yahoo.com,True,2018-08-15,5,65.62
# kevin,Kevin,Carter,kevin8487@ward-lopez.com,True,2018-03-17,5,6.68
# kim1649,Stephen,Kim,stephen9674@gmail.com,True,2018-08-22,4,18.25
# kimberly,Kimberly,,kimberly@yahoo.com,False,2018-01-06,5,54.73
# kimberly.decker,Kimberly,Decker,kimberly5373@hotmail.com,False,2018-03-02,3,79.62
# king,Billy,King,billy.king@hotmail.com,True,2018-05-29,4,98.8
# king3246,Brittney,King,brittney@yahoo.com,True,2018-04-15,6,98.79
# kirk,Kirk,Massey,kmassey@hotmail.com,True,2018-05-30,6,62.3
# klein,Ashley,Klein,ashley@gmail.com,True,2018-03-06,3,13.65
# kpratt,Kyle,Pratt,pratt@gmail.com,True,2018-03-17,2,4.51
# kristen1581,Kristen,Thompson,kthompson@yahoo.com,False,2018-03-22,2,85.18
# kristi7553,Kristi,Foster,kfoster@gmail.com,True,2018-06-08,0,40.14
# kristina.miller,Kristina,Miller,miller@gmail.com,True,2018-03-08,7,90.82
# krystal,Krystal,,krystal@hotmail.com,True,2018-05-30,3,46.92
# kyle.gentry,Kyle,Gentry,kgentry@gmail.com,True,2018-08-30,6,42.36
# lacey8987,Lacey,Ball,lacey5080@gmail.com,True,2018-01-02,0,93.49
# laura,Laura,Wells,laura@yahoo.com,True,2018-06-01,3,36.74
# lauren,Lauren,Aguilar,lauren.aguilar@summers.com,False,2018-05-31,4,69.9
# lawrence1685,Derrick,Lawrence,lawrence7507@gmail.com,True,2018-08-05,5,47.29
# lawrence3513,Katherine,Lawrence,lawrence@gmail.com,False,2018-06-23,2,76.63
# lawson,Katherine,Lawson,katherine9625@gmail.com,True,2018-05-13,4,64.14
# lcruz,Lauren,Cruz,lauren@gmail.com,True,2018-04-29,6,87.16
# leah6255,Leah,Black,leah6754@willis.info,True,2018-01-13,1,43.67
# lee,Catherine,Lee,catherine@hotmail.com,True,2018-05-22,5,73.1
# lee3744,Timothy,Lee,lee@hotmail.com,False,2018-06-14,6,77.85
# lewis8579,Christopher,Lewis,christopher.lewis@gmail.com,False,2018-02-24,6,5.68
# lgregory,Leah,Gregory,gregory@gmail.com,True,2018-06-27,3,48.84
# linda,Linda,,linda@hill-ferguson.info,False,2018-03-27,1,38.67
# lindsay.coleman,Lindsay,Coleman,coleman7772@hotmail.com,True,2018-08-23,0,83.02
# lisa,Lisa,Cook,lcook@hotmail.com,True,2018-06-14,2,34.82
# lisa7840,Lisa,Anderson,lisa2797@hotmail.com,True,2018-07-24,4,91.46
# lisa8780,Lisa,,lisa@hotmail.com,True,2018-05-03,3,36.82
# lmoore,Lisa,Moore,moore1489@hotmail.com,True,2018-02-20,1,51.68
# lowe,Albert,Lowe,albert.lowe@lopez.com,True,2018-01-13,1,60.9
# lspencer,Laura,Spencer,spencer@yahoo.com,True,2018-07-07,6,17.59
# lucero5925,Nicholas,Lucero,nicholas@gmail.com,True,2018-04-08,7,34.61
# luis.brooks,Luis,Brooks,brooks7349@jones.com,True,2018-04-23,6,79.61
# mackenzie,Mackenzie,Smith,smith3292@hotmail.com,True,2018-02-21,2,69.5
# madison,Madison,Griffin,madison@gmail.com,True,2018-07-31,0,32.85
# manning8686,Stephen,Manning,stephen@benson.com,True,2018-06-21,6,54.79
# marcus.berry,Marcus,Berry,marcus.berry@stein.com,True,2018-05-14,3,6.81
# margaret,Margaret,Wells,wells4044@yahoo.com,True,2018-04-11,1,47.12
# margaret265,Margaret,,margaret@gmail.com,True,2018-01-05,1,96.14
# maria955,Maria,,maria8257@gmail.com,True,2018-06-26,0,9.87
# mark,Mark,Shaw,shaw4221@yahoo.com,False,2018-01-15,5,6.25
# mark1376,Mark,Hatfield,hatfield@gmail.com,True,2018-05-04,5,49.52
# mark1605,Mark,,mark1905@gmail.com,True,2018-06-15,1,44.92
# mark20,Mark,Hernandez,mhernandez@butler.org,True,2018-04-08,3,84.33
# mark5306,Mark,Lee,mark.lee@thompson.info,True,2018-04-27,7,12.34
# mark8466,Mark,,mark2286@hotmail.com,False,2018-06-01,6,5.11
# martha.willis,Martha,Willis,martha5711@gmail.com,False,2018-09-07,5,86.08
# martha6969,Martha,Dominguez,dominguez@hensley.com,False,2018-09-04,7,42.36
# martin,Caroline,Martin,caroline@hotmail.com,True,2018-08-30,3,16.55
# martinez,Alicia,Martinez,martinez@hotmail.com,False,2018-08-16,5,53.45
# massey2102,Philip,Massey,philip@gmail.com,True,2018-04-28,4,25.04
# matthew5486,Matthew,Weeks,matthew@hotmail.com,True,2018-04-23,5,35.25
# matthew7940,Matthew,Smith,msmith@hotmail.com,True,2018-01-27,4,73.55
# mays,Jacob,Mays,jmays@yahoo.com,True,2018-03-01,4,83.85
# mbrown,Madison,Brown,madison1633@yahoo.com,False,2018-03-18,2,87.56
# mburke,Mark,Burke,burke9543@gmail.com,False,2018-03-03,7,20.5
# mcarroll,Mark,Carroll,mark.carroll@yahoo.com,True,2018-09-09,5,64.46
# mcclain9882,Amy,Mcclain,amy@yahoo.com,True,2018-09-24,6,44.28
# mcguire,George,Mcguire,george.mcguire@mcdowell.biz,True,2018-03-04,2,86.74
# medina891,Rose,Medina,rose.medina@wolfe.net,True,2018-01-01,5,54.68
# megan.terry,Megan,Terry,megan8248@yahoo.com,True,2018-05-19,3,80.24
# melanie,Melanie,,melanie4308@hotmail.com,False,2018-07-30,1,44.94
# melissa.mendoza,Melissa,Mendoza,mendoza7698@yahoo.com,True,2018-01-18,2,72.05
# melvin9380,Melvin,Foster,foster5075@marshall.com,True,2018-02-21,3,30.39
# mevans,Matthew,Evans,matthew@yahoo.com,True,2018-04-05,2,13.55
# michael,Michael,,michael952@hotmail.com,True,2018-01-28,0,78.56
# michael.olson,Michael,Olson,olson5084@gmail.com,True,2018-07-08,3,88.39
# michael.williams,Michael,Williams,michael@yahoo.com,True,2018-08-19,7,11.73
# michael7792,Michael,,michael@vega.com,False,2018-08-05,5,32.38
# michelle4225,Michelle,Horne,michelle.horne@yahoo.com,True,2018-01-15,0,65.03
# miguel.gamble,Miguel,Gamble,miguel9530@hotmail.com,False,2018-08-26,6,1.11
# mikayla.west,Mikayla,West,west@hotmail.com,True,2018-07-06,6,2.28
# miller,Joshua,Miller,joshua7805@yahoo.com,True,2018-09-17,6,44.45
# miller4208,Tina,Miller,miller@yahoo.com,False,2018-08-10,5,55.94
# miller8552,Hannah,Miller,hannah5934@gmail.com,True,2018-06-29,6,8.12
# miranda6426,Miranda,Rogers,miranda.rogers@gmail.com,True,2018-08-06,0,20.51
# mjohnson,Mathew,Johnson,johnson1466@yahoo.com,False,2018-06-29,1,79.95
# moore,Yvonne,Moore,yvonne5907@gmail.com,True,2018-07-10,5,52.46
# moore7025,Mark,Moore,mmoore@gonzalez.com,True,2018-07-30,1,82.6
# mpaul,Melissa,Paul,paul2182@hotmail.com,True,2018-07-15,2,66.94
# mshort,Michael,Short,michael8762@yahoo.com,True,2018-05-29,6,83.18
# msolis,Michael,Solis,solis7414@yahoo.com,True,2018-05-31,7,93.25
# nancy,Nancy,Williams,williams8331@gmail.com,True,2018-05-14,4,41.15
# nathaniel,Nathaniel,Goodman,ngoodman@hotmail.com,True,2018-09-06,2,87.98
# nelson,Laura,Nelson,nelson6092@yahoo.com,True,2018-08-02,7,34.47
# nicholas.padilla,Nicholas,Padilla,nicholas@olsen.com,True,2018-06-10,6,88.74
# nicholas.travis,Nicholas,Travis,nicholas@hotmail.com,False,2018-05-22,7,92.42
# nicholas5556,Nicholas,Walsh,nwalsh@nelson.info,True,2018-06-24,1,86.62
# nichols,Nicholas,Nichols,nicholas9581@hotmail.com,True,2018-06-20,4,86.06
# ortiz5962,Julia,Ortiz,jortiz@rogers.com,True,2018-09-10,5,54.45
# owens,Kristine,Owens,owens@hotmail.com,True,2018-08-27,1,21.64
# paige.lewis,Paige,Lewis,paige@hotmail.com,True,2018-07-16,1,75.58
# palmer,Michael,Palmer,michael.palmer@gmail.com,True,2018-03-24,2,53.85
# pamela,Pamela,Lynch,pamela.lynch@yahoo.com,True,2018-09-25,0,85.82
# parker,Michelle,Parker,michelle@gmail.com,True,2018-09-17,2,82.78
# parker4621,Caleb,Parker,caleb@yahoo.com,True,2018-07-16,2,68.69
# parsons,Steven,Parsons,parsons@hotmail.com,True,2018-08-09,6,68.76
# patricia,Patricia,Smith,patricia@gmail.com,True,2018-09-25,3,71.36
# patricia2613,Patricia,Wang,pwang@yahoo.com,True,2018-07-06,1,43.59
# paul6364,Paul,Hill,paul2980@hotmail.com,True,2018-02-28,1,98.62
# paul9642,Paul,Dalton,dalton4600@gmail.com,True,2018-02-23,0,61.26
# paula7980,Paula,Larson,plarson@hotmail.com,True,2018-02-09,2,44.54
# payne,Tyler,Payne,tyler.payne@wagner.com,True,2018-02-19,2,56.87
# peter,Peter,Grimes,pgrimes@yahoo.com,True,2018-09-02,0,96.79
# peters1942,Christopher,Peters,christopher.peters@gmail.com,False,2018-07-04,4,6.05
# phillips5654,Vanessa,Phillips,vanessa.phillips@yahoo.com,True,2018-02-03,4,68.96
# porter,Mark,Porter,mark@hotmail.com,True,2018-02-12,4,48.56
# rachel,Rachel,,rachel5266@hotmail.com,True,2018-03-12,6,14.81
# rachel.ellison,Rachel,Ellison,ellison@gmail.com,True,2018-04-08,0,65.31
# rebecca,Rebecca,Yoder,rebecca.yoder@miranda.biz,True,2018-08-12,1,16.44
# rebecca848,Rebecca,,rebecca759@hotmail.com,False,2018-06-23,0,22.73
# reid,Samuel,Reid,samuel.reid@gmail.com,True,2018-06-24,5,0.73
# rholmes,Robert,Holmes,rholmes@yahoo.com,True,2018-05-04,4,55.37
# robert,Robert,Brown,robert@gmail.com,True,2018-07-12,3,53.16
# robert284,Robert,Davidson,robert.davidson@gmail.com,True,2018-05-21,3,32.63
# robert8280,Robert,,robert@gmail.com,True,2018-09-22,2,56.89
# roberts,David,Roberts,david.roberts@hotmail.com,True,2018-06-09,2,29.5
# robinson,Teresa,Robinson,trobinson@hotmail.com,True,2018-03-10,1,17.31
# robinson5269,Dan,Robinson,drobinson@yahoo.com,True,2018-06-15,2,79.28
# rodriguez,Amy,Rodriguez,amy.rodriguez@gmail.com,True,2018-04-29,0,15.96
# rodriguez5768,Joshua,Rodriguez,joshua.rodriguez@hotmail.com,True,2018-01-04,3,51.06
# rodriguez585,Renee,Rodriguez,rodriguez6865@yahoo.com,True,2018-07-04,0,52.35
# rodriguez9475,Amanda,Rodriguez,amanda@yahoo.com,False,2018-04-30,6,77.81
# roger,Roger,Rangel,roger.rangel@gmail.com,True,2018-03-04,0,87.21
# rogers,Emily,Rogers,emily6420@gmail.com,True,2018-07-24,7,69.07
# roman7509,Amy,Roman,amy4377@lang.org,True,2018-03-21,5,55.53
# rose.eaton,Rose,Eaton,reaton@gmail.com,True,2018-01-21,7,90.03
# ross9165,Jacqueline,Ross,jacqueline.ross@hawkins.com,True,2018-09-11,0,24.44
# rsnow,Randy,Snow,randy5950@johnson.com,True,2018-01-31,5,40.78
# ruiz2577,Tommy,Ruiz,ruiz@hotmail.com,False,2018-02-21,2,54.8
# ruth,Ruth,Randall,randall@yahoo.com,False,2018-01-28,0,70.39
# sabrina.haas,Sabrina,Haas,sabrina.haas@hotmail.com,True,2018-03-25,2,11.6
# samuel.conner,Samuel,Conner,conner4407@roberts.info,True,2018-03-30,5,0.18
# samuel1489,Samuel,Dominguez,samuel@gmail.com,False,2018-01-24,4,31.53
# sanders,Joy,Sanders,jsanders@hotmail.com,True,2018-09-15,0,34.5
# sandra.vaughn,Sandra,Vaughn,vaughn@hotmail.com,True,2018-06-11,5,79.74
# sandra2071,Sandra,,sandra63@yahoo.com,True,2018-01-18,1,45.22
# sandra2565,Sandra,Zuniga,sandra5507@hotmail.com,True,2018-04-21,6,54.98
# sarah,Sarah,Ibarra,ibarra6062@gmail.com,False,2018-06-13,6,16.98
# sarah.evans,Sarah,Evans,evans1842@hotmail.com,False,2018-03-20,6,3.17
# sbennett,Steven,Bennett,sbennett@yahoo.com,True,2018-02-07,5,97.38
# scott3928,Scott,,scott@yahoo.com,True,2018-02-26,5,72.02
# sexton,David,Sexton,david.sexton@hotmail.com,True,2018-07-29,2,21.81
# sfinley,Samuel,Finley,samuel@gmail.com,False,2018-03-09,2,83.62
# shari,Shari,Williams,shari@hotmail.com,True,2018-02-06,6,67.04
# shelly,Shelly,Johnson,johnson7039@yahoo.com,True,2018-05-29,0,18.03
# sheri.clements,Sheri,Clements,sheri@gmail.com,True,2018-09-08,3,62.13
# shernandez,Shannon,Hernandez,hernandez8777@gmail.com,True,2018-09-04,4,34.11
# sherry6113,Sherry,,sherry@hotmail.com,True,2018-04-06,7,21.79
# singh2309,Carol,Singh,carol.singh@hotmail.com,True,2018-02-15,6,34.22
# smercer,Scott,Mercer,smercer@yahoo.com,True,2018-09-19,2,76.77
# smith,William,Smith,smith1172@hotmail.com,False,2018-05-02,4,65.79
# smith6248,James,Smith,smith@gmail.com,False,2018-03-30,1,19.23
# smith6903,Susan,Smith,ssmith@yahoo.com,True,2018-09-06,6,27.53
# smith8419,Shawn,Smith,shawn@hotmail.com,True,2018-06-08,2,58.85
# smith9087,Kimberly,Smith,kimberly@hotmail.com,True,2018-01-01,6,54.04
# smoyer,Sydney,Moyer,sydney7488@hotmail.com,True,2018-01-03,2,90.87
# sophia.perez,Sophia,Perez,perez@hotmail.com,True,2018-09-05,1,27.71
# spadilla,Susan,Padilla,susan6496@kelly-cruz.info,True,2018-05-01,3,88.32
# spence,James,Spence,spence@gmail.com,True,2018-04-20,0,47.28
# sstanton,Samantha,Stanton,samantha.stanton@gmail.com,True,2018-01-25,3,43.05
# stanley7729,Stanley,Spence,stanley.spence@gmail.com,False,2018-03-24,3,62.15
# staylor,Samantha,Taylor,samantha@yahoo.com,True,2018-04-19,6,4.92
# stein,Douglas,Stein,stein@yahoo.com,False,2018-01-02,1,48.52
# stephanie4610,Stephanie,Fuller,stephanie9430@nguyen.com,False,2018-04-14,5,66.21
# stephanie5596,Stephanie,Owens,stephanie.owens@gmail.com,True,2018-04-08,3,29.75
# steven,Steven,Conner,conner7093@gmail.com,False,2018-02-14,4,83.16
# steven3847,Steven,Jackson,sjackson@yahoo.com,True,2018-04-08,7,16.95
# stevens8089,Lisa,Stevens,lisa@davis.com,True,2018-06-16,1,39.29
# sthompson,Sarah,Thompson,sarah@rodriguez.biz,False,2018-05-05,2,9.29
# sward,Susan,Ward,sward@gmail.com,False,2018-06-21,2,39.5
# tamara,Tamara,,tamara6323@gmail.com,True,2018-06-15,5,16.78
# tammy.brown,Tammy,Brown,tammy.brown@yahoo.com,True,2018-07-10,2,6.3
# tammy7432,Tammy,Pacheco,tammy.pacheco@yahoo.com,True,2018-05-30,4,7.1
# tanya.carlson,Tanya,Carlson,tcarlson@hotmail.com,True,2018-01-13,0,27.79
# tara.clark,Tara,Clark,tara4681@hotmail.com,False,2018-04-18,7,65.16
# taylor1468,Taylor,Long,tlong@hotmail.com,True,2018-04-03,0,8.45
# taylor2783,Taylor,,taylor@lewis.info,True,2018-01-07,1,11.19
# taylor7649,Michael,Taylor,taylor2184@gmail.com,True,2018-08-18,7,83.97
# tbender,Travis,Bender,travis@yahoo.com,False,2018-07-30,0,50.55
# tgeorge,Travis,George,george6344@chavez-jackson.com,True,2018-03-11,0,37.59
# theresa5909,Theresa,Mitchell,theresa@hotmail.com,True,2018-08-30,5,63.46
# thomas.price,Thomas,Price,price@hotmail.com,True,2018-09-21,6,10.16
# thompson2327,Troy,Thompson,troy.thompson@gmail.com,False,2018-04-24,7,98.09
# thompson2826,Frank,Thompson,thompson1904@hotmail.com,False,2018-09-21,0,41.82
# thompson9387,Patrick,Thompson,pthompson@yahoo.com,True,2018-05-11,3,36.39
# tiffany.bowen,Tiffany,Bowen,tiffany@hamilton.biz,True,2018-03-12,6,86.38
# timothy.heath,Timothy,Heath,heath6503@gmail.com,True,2018-06-09,6,76.78
# timothy3285,Timothy,Davis,davis@jones.net,True,2018-08-04,5,43.24
# tina3658,Tina,,tina@hotmail.com,True,2018-08-26,2,17.41
# tjohnson,Taylor,Johnson,johnson5212@gmail.com,True,2018-06-10,3,93.84
# tmaxwell,Tiffany,Maxwell,tiffany@gmail.com,True,2018-05-10,6,3.9
# torres,Taylor,Torres,taylor.torres@ware.info,True,2018-01-12,7,21.88
# tstewart,Tricia,Stewart,tricia@yahoo.com,True,2018-06-04,4,22.33
# twebster,Taylor,Webster,taylor.webster@gmail.com,True,2018-05-25,0,51.8
# twhite,Timothy,White,white5136@hotmail.com,True,2018-07-06,5,99.9
# tyler.zavala,Tyler,Zavala,tyler.zavala@murray.com,True,2018-07-08,2,5.98
# valerie,Valerie,Cannon,valerie.cannon@yahoo.com,True,2018-04-30,2,28.31
# vang,Tammie,Vang,vang@gmail.com,True,2018-07-04,5,24.61
# victor,Victor,Tanner,victor@sullivan-fowler.org,False,2018-09-20,1,53.55
# walsh,Kelli,Walsh,walsh@hotmail.com,True,2018-02-08,1,14.7
# walters2042,Leslie,Walters,walters8435@gmail.com,True,2018-07-27,2,40.83
# watts,Jenna,Watts,jenna@gmail.com,True,2018-03-12,0,54.5
# wbrown,Wesley,Brown,wesley@hotmail.com,True,2018-06-24,7,35.64
# wesley.hayes,Wesley,Hayes,wesley.hayes@gmail.com,True,2018-08-17,3,90.44
# west,Brian,West,west@yahoo.com,True,2018-01-30,3,52.83
# wilkins,David,Wilkins,david1254@goodman.info,True,2018-08-06,4,52.15
# william,William,,william@hotmail.com,True,2018-06-13,4,4.69
# william.lee,William,Lee,lee5646@yahoo.com,True,2018-05-30,3,67.65
# william2231,William,Douglas,douglas8813@yahoo.com,True,2018-05-19,4,85.32
# william4588,William,Pittman,william.pittman@gmail.com,True,2018-04-11,2,2.04
# william6714,William,,william5677@yahoo.com,True,2018-04-26,3,74.65
# wilson,Robert,Wilson,robert@yahoo.com,False,2018-05-16,5,59.75
# wking,Wanda,King,wanda.king@holt.com,True,2018-06-01,2,67.08
# wright3590,Jacqueline,Wright,jacqueline.wright@gonzalez.com,True,2018-02-08,6,18.48
# young,Jessica,Young,jessica4028@yahoo.com,True,2018-07-17,4,75.39
# zachary.neal,Zachary,Neal,zneal@gmail.com,True,2018-07-26,1,39.9

# %% [markdown]
# Notice how the first line is a header row. It has column names in it. By default, it will be assumed that the first row is your header row.
#
# Also note how the first column of that header row is empty...the values below in that first column appear to be usernames.  They are what we want for the index.
#
# We can use the `index_col` parameter of the `pandas.read_csv` function.

# %%
# Create a new `DataFrame` and set the index to the first column
users = pd.read_csv(users_file_name, index_col = 0)

# %% [markdown]
# ## Explore your imported DataFrame

# %% [markdown]
# A quick way to check and see if you got your CSV file read correctly is to use the [`DataFrame.head`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html) method. This gives you the first **x** number of rows. The head method, by default, returns 5 records. You can specify the number you want as the first argument, for instance `users.head(10)` will return the first 10 rows.

# %%
users.head(20)
# Out:
#                first_name last_name                          email  \
# aaron               Aaron     Davis            aaron6348@gmail.com
# acook             Anthony      Cook                 cook@gmail.com
# adam.saunders        Adam  Saunders                 adam@gmail.com
# adrian             Adrian      Fang  adrian.fang@teamtreehouse.com
# adrian.blair       Adrian     Blair           adrian9335@gmail.com
# alan9443             Alan      Pope               pope@hotmail.com
# alexander7808   Alexander     Moore      alexander.moore@gmail.com
# alvarado           Denise  Alvarado           alvarado@hotmail.com
# alvarez              John   Alvarez           john4346@hotmail.com
# amanda             Amanda     Lynch               alynch@gmail.com
# amiller              Anne    Miller             miller@hotmail.com
# andersen             Mark  Andersen        mark.andersen@yahoo.com
# andrade           Melissa   Andrade             mandrade@yahoo.com
# andrew.alvarez     Andrew   Alvarez           aalvarez@hotmail.com
# andrew.wells       Andrew     Wells           andrew9976@yahoo.com
# andrew6216         Andrew     Bryan               andrew@gmail.com
# andrew6347         Andrew    Horton      andrew.horton@hotmail.com
# angela7209         Angela   Collins          collins5797@yahoo.com
# anthony1788       Anthony    Valdez              anthony@gmail.com
# anthony3761       Anthony       NaN          anthony9581@gmail.com
#
#                 email_verified signup_date  referral_count  balance
# aaron                     True  2018-08-31               6    18.14
# acook                     True  2018-05-12               2    55.45
# adam.saunders            False  2018-05-29               3    72.12
# adrian                    True  2018-04-28               3    30.01
# adrian.blair              True  2018-06-16               7    25.85
# alan9443                  True  2018-04-17               0    56.09
# alexander7808            False  2018-03-27               2    87.71
# alvarado                  True  2018-09-07               6    26.72
# alvarez                   True  2018-09-18               6    49.62
# amanda                    True  2018-09-18               2    43.76
# amiller                  False  2018-06-02               5    86.28
# andersen                  True  2018-08-21               3    75.69
# andrade                   True  2018-01-06               3    83.22
# andrew.alvarez           False  2018-08-01               0    81.66
# andrew.wells              True  2018-06-13               5    76.07
# andrew6216                True  2018-04-01               1    71.42
# andrew6347                True  2018-02-01               2    85.73
# angela7209                True  2018-05-05               7    29.52
# anthony1788               True  2018-06-30               5    70.70
# anthony3761               True  2018-08-16               6    59.81

# %% [markdown]
# Nice! We got it.  So let's see how many rows we have.  There are a couple of ways.

# %%
# Pythonic approach still works
len(users)
# Out:
# 475

# %% [markdown]
# *Side note*: This length call is quick. Under the covers this `DataFrame.__len__` call is actually performing a `len(df.index)`, counting the rows by using the index. You might see older code that uses the style of `len(df.index)` to get a count of rows. As of pandas version 0.11, `len(df)` is the same as `len(df.index)`.

# %% [markdown]
# The `DataFrame.shape` property works just like `np.array.shape` does. This is the length of each axis of your data frame, rows and columns.

# %%
users.shape
# Out:
# (475, 7)

# %% [markdown]
# ### Exploring from a bird's eye view

# %% [markdown]
# #### Counts

# %% [markdown]
# The [`DataFrame.count`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.count.html) method will count up each column for how many non-empty values we have.

# %%
users.count()
# Out:
# first_name        475
# last_name         430
# email             475
# email_verified    475
# signup_date       475
# referral_count    475
# balance           475
# dtype: int64

# %% [markdown]
# Most of our columns include values for each row, but looks like **last_name** has some missing ones.  The missing data will show up as `np.nan` -- NumPy's not a number -- in those records.
#
#
# The `count` method is data missing aware.

# %% [markdown]
# Remember that a `DataFrame` has the ability to contain multiple data types or [`dtypes`](https://pandas.pydata.org/pandas-docs/stable/basics.html#basics-dtypes).
#
# You can use the `DataFrame.dtypes` to see the `dtype` of each column.

# %% [markdown]
# #### Data types

# %%
users.dtypes
# Out:
# first_name         object
# last_name          object
# email              object
# email_verified       bool
# signup_date        object
# referral_count      int64
# balance           float64
# dtype: object

# %% [markdown]
# As you can see, most of the data types of these columns were inferred, or assumed, correctly.  See how automatically **`email_verified`** is `bool`, **`referral_count`** is an integer, and **`balance`** a float. This happened when we used `pd.read_csv`.
#
# One thing to note though that the **`signup_date`** field is an `object` and not a `datetime`. You can convert these during or after import if you need to, and we'll do some of that later in this course.

# %% [markdown]
# #### Describe your data
# The [`DataFrame.describe`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html) method is a great way to get a vibe for **all numeric data** in your `DataFrame`.  You'll notice only columns that have numeric data are returned, and ones with booleans or text, like **`email_verified`** and **`first_name`** are left out.
#
#
# You'll see lots of different aggregations.

# %%
users.describe()
# Out:
#        referral_count     balance
# count      475.000000  475.000000
# mean         3.429474   49.933263
# std          2.281085   28.280448
# min          0.000000    0.050000
# 25%          2.000000   25.305000
# 50%          3.000000   51.570000
# 75%          5.000000   74.480000
# max          7.000000   99.900000

# %% [markdown]
# Most of these aggregations are available by themselves as well

# %%
# The mean or average
users.mean()
# Out:
# email_verified     0.818947
# referral_count     3.429474
# balance           49.933263
# dtype: float64

# %%
# Standard deviation
users.std()
# Out:
# email_verified     0.385468
# referral_count     2.281085
# balance           28.280448
# dtype: float64

# %%
# The minimum of each column
users.min()
# Out:
# first_name                       Aaron
# email             aalvarez@hotmail.com
# email_verified                   False
# signup_date                 2018-01-01
# referral_count                       0
# balance                           0.05
# dtype: object

# %%
# The maximum of each column
users.max()
# Out:
# first_name                Zachary
# email             zneal@gmail.com
# email_verified               True
# signup_date            2018-09-25
# referral_count                  7
# balance                      99.9
# dtype: object

# %% [markdown]
# Since columns are in reality a `Series` you can quickly access their counts of different values using the [`value_counts`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) method.

# %%
users['email_verified'].value_counts()
# Out:
# True     389
# False     86
# Name: email_verified, dtype: int64

# %% [markdown]
# By default the value counts are sorted descending, so the most frequent are at top.

# %%
# Most common first name
users['first_name'].value_counts().head(10)
# Out:
# Mark           11
# David          10
# Michael         9
# Jennifer        7
# Emily           7
# William         7
# Joshua          7
# Christopher     7
# Robert          7
# Jason           6
# Name: first_name, dtype: int64

# %% [markdown]
# ### Rearranging your data
# You can create a new `DataFrame` that is sorted by using the [`sort_values`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html) method.
#
# Let's sort the DataFrame so that the user with the highest **`balance`** is at the top. By default, ascending order is assumed, you can change that by setting the `ascending` keyword argument to `False`.

# %%
users.sort_values(by='balance', ascending=False).head()
# Out:
#            first_name last_name                    email  email_verified  \
# twhite        Timothy     White    white5136@hotmail.com            True
# karen.snow      Karen      Snow          ksnow@yahoo.com            True
# king            Billy      King   billy.king@hotmail.com            True
# king3246     Brittney      King       brittney@yahoo.com            True
# crane203      Valerie     Crane  valerie7051@hotmail.com            True
#
#            signup_date  referral_count  balance
# twhite      2018-07-06               5    99.90
# karen.snow  2018-05-06               2    99.38
# king        2018-05-29               4    98.80
# king3246    2018-04-15               6    98.79
# crane203    2018-05-12               3    98.69

# %%
users = users.sort_values(by='balance', ascending=False)
users.head()
# Out:
#            first_name last_name                    email  email_verified  \
# twhite        Timothy     White    white5136@hotmail.com            True
# karen.snow      Karen      Snow          ksnow@yahoo.com            True
# king            Billy      King   billy.king@hotmail.com            True
# king3246     Brittney      King       brittney@yahoo.com            True
# crane203      Valerie     Crane  valerie7051@hotmail.com            True
#
#            signup_date  referral_count  balance
# twhite      2018-07-06               5    99.90
# karen.snow  2018-05-06               2    99.38
# king        2018-05-29               4    98.80
# king3246    2018-04-15               6    98.79
# crane203    2018-05-12               3    98.69

# %% [markdown]
# You'll notice that `sort_values` call actually created a new `DataFrame`. If you want to permanently change the sort from the default (sorted by index), you can pass `True` as an argument to the `inplace` keyword parameter.

# %%
# Sort first by last_name and then first_name. By default, np.nan show up at the end
users.sort_values(by=['last_name', 'first_name'])
# Sort order is now changed
users.head(20)
# Out:
#            first_name last_name                    email  email_verified  \
# twhite        Timothy     White    white5136@hotmail.com            True
# karen.snow      Karen      Snow          ksnow@yahoo.com            True
# king            Billy      King   billy.king@hotmail.com            True
# king3246     Brittney      King       brittney@yahoo.com            True
# crane203      Valerie     Crane  valerie7051@hotmail.com            True
#
#            signup_date  referral_count  balance
# twhite      2018-07-06               5    99.90
# karen.snow  2018-05-06               2    99.38
# king        2018-05-29               4    98.80
# king3246    2018-04-15               6    98.79
# crane203    2018-05-12               3    98.69

# %% [markdown]
# And if you want to **sort by the index (or label)**, like it was originally, you can use the `sort_index` method.

# %%
users.sort_index(inplace=True)
users.head()
